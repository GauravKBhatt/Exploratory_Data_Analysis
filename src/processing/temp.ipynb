# %%
import pandas as pd

# %%
df_bikes = pd.read_csv(r"d:/Coding/Exploratory_Data_Analysis/data/Scraped/Unclean/current_bikes_scraped_hamrobazar.csv",on_bad_lines='skip')
df_bikes.head()
print(df_bikes.shape[0],df_bikes.shape[1])

print('\n\n\n')
df_cars = pd.read_csv(r"d:/Coding/Exploratory_Data_Analysis/data/Scraped/Unclean/current_cars_scraped_hamrobazar.csv",on_bad_lines='skip')
df_cars.head()
print(df_cars.shape[0],df_cars.shape[1])
# Out:
# 1716 12
#
#
#
#
# 1523 12
