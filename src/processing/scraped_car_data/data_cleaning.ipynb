# %% [markdown]
# **Necessary Imports**

# %%
import pandas as pd 
import numpy as np 
import re 
import matplotlib.pyplot as plt

# %% [markdown]
# **Loading the Necessary Files**

# %%
df = pd.read_csv(r"d:/Coding/Exploratory_Data_Analysis/data/Scraped/Unclean/current_cars_scraped_hamrobazar.csv",on_bad_lines='skip')
df.head()
# Out:
#                                                 Name      Price   Used For  \
# 0            Nissan Sunny 1.6 fully fresh 9803656430   880000.0        NaN
# 1                  Hyundai i10 2009model with option  1055000.0        NaN
# 2  Santro   Hyundai 2013 model  super fresh 2user...  1515000.0  Personal
# 3     Santro   Hyundai 2013 model super fresh 2user   1515000.0  Personal
# 4                                   i10 magna 1200cc  1175000.0        NaN
#
#   Warranty  Transmission     Colour Make Year  \
# 0      NaN     Manual2WD        NaN      2007
# 1      NaN  Manual - 2WD  Dark Blue      2009
# 2      NaN       Auto2WD     Marun       2014
# 3      NaN       Auto2WD     Marun       2013
# 4      NaN  Manual - 2WD       blue      2009
#
#                                             Features Mileage Engine (CC)  \
# 0                                                NaN      15        1600
# 1  Fresh car with great engine and on sale plus c...      16        1100
# 2                                 Basic full option   15-18      1100 CC
# 3                                 Basic full option    15-18    1100 CC
# 4             power steering power windows ac heater      14        1200
#
#      Fuel Kilometer Run               Types
# 0  Petrol           NaN               Sedan
# 1  Petrol           NaN  Mid Size Hatchback
# 2  Petrol         77000    MidSizeHatchback
# 3  Petrol        77000     MidSizeHatchback
# 4  Petrol         62000     Small Hatchback

# %% [markdown]
# **Changing the columns into Snake Case**

# %%
df.columns = (
    df.columns               
      .str.lower()                  # convert to lowercase
      .str.replace('[^a-zA-Z0-9 ]', '', regex=True)   # remove special chars ()&./
      .str.replace(' +', '_', regex=True)  # convert spaces to underscores
)
df.head()
# Out:
#                                            name    used_for   warranty  \
# 0  Maruti Suzuki Wagon R VXi 2016 "Single Hand"   Manual2WD        Red
# 1  Kia Seltos 2020 Diesel with Banking Facility  CompactSUV       2020
# 2                     suzuki baleno 2016 model        Sedan       2016
# 3               Renault Duster Rxl Petrol (2017   60343km )  Manual2WD
# 4                           Polo trendline 2019   Manual2WD     Silver
#
#      transmission     colour  make_year features           mileage engine_cc  \
# 0            2016        998     Petrol    51215    SmallHatchback       NaN
# 1           57000  Manual2WD     Diesel      NaN               NaN       NaN
# 2          1200cc  dark blue  Manual2WD   Petrol               NaN       NaN
# 3  Woodland Brown       2017         15     1498            Petrol     60343
# 4            2019        999     Petrol    63000  MidSizeHatchback       NaN
#
#       fuel kilometer_run types
# 0      NaN           NaN   NaN
# 1      NaN           NaN   NaN
# 2      NaN           NaN   NaN
# 3  SUVJeep           NaN   NaN
# 4      NaN           NaN   NaN

# %% [markdown]
# **Dropping Duplicate**

# %%
df.drop_duplicates(subset=["name"], keep="first")
# Out:
#                                               name        used_for  \
# 0     Maruti Suzuki Wagon R VXi 2016 "Single Hand"       Manual2WD
# 1     Kia Seltos 2020 Diesel with Banking Facility      CompactSUV
# 2                        suzuki baleno 2016 model            Sedan
# 3                  Renault Duster Rxl Petrol (2017       60343km )
# 4                              Polo trendline 2019       Manual2WD
# ...                                            ...             ...
# 1453                               Ford freestyle     Manual - 2WD
# 1454        Suzuki dezire vxi 2009 full condition         Private
# 1455                             Hyundai Creta SX+     Compact SUV
# 1456                          SML Tipper for Sale!  Not Applicable
# 1457  Renault Duster 2017 Model (Only 28000km Run)        Company
#
#           warranty    transmission     colour      make_year features  \
# 0              Red            2016        998         Petrol    51215
# 1             2020           57000  Manual2WD         Diesel      NaN
# 2             2016          1200cc  dark blue      Manual2WD   Petrol
# 3        Manual2WD  Woodland Brown       2017             15     1498
# 4           Silver            2019        999         Petrol    63000
# ...            ...             ...        ...            ...      ...
# 1453         White  Within My Area       2018           1200   Petrol
# 1454            No    Manual - 2WD       Grey           2009  Manual
# 1455          2016            1500      white   Manual - 2WD   Petrol
# 1456  Manual - 4WD            Blue       2018             12     3452
# 1457  Manual - 2WD         Coffee        2017  Fully loaded        14
#
#                mileage           engine_cc     fuel kilometer_run types
# 0       SmallHatchback                 NaN      NaN           NaN   NaN
# 1                  NaN                 NaN      NaN           NaN   NaN
# 2                  NaN                 NaN      NaN           NaN   NaN
# 3               Petrol               60343  SUVJeep           NaN   NaN
# 4     MidSizeHatchback                 NaN      NaN           NaN   NaN
# ...                ...                 ...      ...           ...   ...
# 1453             45000  Mid Size Hatchback      NaN           NaN   NaN
# 1454                25              Petrol    55000         Sedan   NaN
# 1455               NaN                 NaN      NaN           NaN   NaN
# 1456            Diesel               12000   Others           NaN   NaN
# 1457              1500              Petrol    25000    SUV / Jeep   NaN
#
# [929 rows x 12 columns]

# %% [markdown]
# **Changing the KW to cc**

# %%
def convert_kw_to_cc(value):
    if pd.isna(value):
        return value
    
    # Convert to string for processing
    value_str = str(value).strip().lower()
    
    # Check if 'kw' is in the value
    if 'kw' in value_str:
        # Extract numeric part using regex
        match = re.search(r'(\d+\.?\d*)', value_str)
        if match:
            numeric_value = float(match.group(1))
            # Multiply by 24.25 and return
            return numeric_value * 24.25
    
    # Return original value if no 'kw' found
    return value

df['engine_cc']= df['engine_cc'].apply(convert_kw_to_cc)

# %% [markdown]
# **Cleaning Numeric Columns**

# %%
def clean_numeric_columns(df, columns):
    for col in columns:
        df[col] = df[col].astype(str).str.extract(r'(\d+(?:\.\d+)?)')
        df[col] = pd.to_numeric(df[col], errors='coerce')
    return df

df = clean_numeric_columns(df,['make_year','mileage','engine_cc','kilometer_run'])
df.head()
# Out:
#                                                 name  \
# 0  Hyundai | i20 Active S | TDi | 2015 | Hatchbac...
# 1                    Excellent car on sale (Hyundai)
# 2                          TATA 407 Container (Tata)
# 3                        4x4 swaraj Mazda (Mahindra)
# 4        i20 Active good for used few time (Hyundai)
#
#                         price     used_for   transmisson      colour  \
# 0  रू. 24,75,000रू. 25,00,000  Private Use     Manual2WD       Brown
# 1                रू. 7,50,000          NaN       Auto2WD  Light blue
# 2                रू. 7,00,000          NaN  Manual - 2WD       White
# 3                रू. 6,00,000          NaN  Manual - 4WD         NaN
# 4                     रू. 375          NaN    Auto - 2WD       white
#
#    make_year  mileage  engine_cc    fuel  kilometer_run waranty  types
# 0       2015     14.0     1400.0  Petrol        42000.0     NaN    NaN
# 1       2005     11.0     1399.0  Petrol        87412.0     NaN    NaN
# 2       2013      NaN     2956.0  Diesel        60000.0     NaN    NaN
# 3       2017      NaN        NaN  Diesel            NaN     NaN    NaN
# 4       2019     17.0     1200.0  Petrol         2400.0     NaN    NaN

# %% [markdown]
# **Since, ['engine_cc','make_year','price','mileage','kilometer_run'] are the critical columns thus, we are dropping those entries  where 2 out of 3 columns are missing. **

# %%
def sixty_percent_or_more_columns_missing(df,critical_columns):
    missing_count = df[critical_columns].isna().sum(axis=1)
    to_drop = missing_count >= 3
    print(f"Length of outliers:{len(df.loc[to_drop, critical_columns])}\n\n")

# %%
sixty_percent_or_more_columns_missing(df,['engine_cc', 'make_year', 'price','mileage','kilometer_run'])
# Out:
# Length of outliers:61

# %% [markdown]
# **Using capped_mputation of kilometers_run on the basis of make_year**

# %%
df['make_year'] = pd.to_numeric(df['make_year'], errors='coerce')
df['kilometer_run'] = pd.to_numeric(df['kilometer_run'], errors='coerce')
# Calculate actual km/year from existing data
df['km_per_year'] = df['kilometer_run'] / (2024 - df['make_year'])

# Get realistic median km/year from your dataset
cap_value = 66000 + 1.5 * 34000  # Use your actual rate but cap at Q3 + 1.5*IQR (standard outlier threshold)
actual_km_per_year = df['km_per_year'].median()  # Likely 5,000-8,000
print(f"Actual km/year in dataset: {actual_km_per_year}")

# Now impute using YOUR data's pattern
missing_mask = df['kilometer_run'].isna()
df.loc[missing_mask, 'kilometer_run'] = np.minimum(
    (2024 - df.loc[missing_mask, 'make_year']) * 4788,
    cap_value
)
df.drop('km_per_year',axis=1,inplace=True)
# Out:
# Actual km/year in dataset: 4777.777777777777

# %%
sixty_percent_or_more_columns_missing(df,['engine_cc', 'make_year', 'price','mileage','kilometer_run'])
# Out:
# Length of outliers:0

# %% [markdown]
# **Imputing Mileage on the basis of engine_cc**

# %%
df['engine_cc'] = pd.to_numeric(df['engine_cc'], errors='coerce')
# Group by fuel type and engine size categories
df['engine_category'] = pd.cut(df['engine_cc'], 
                                bins=[0, 1200, 1600, 2000, 5000],
                                labels=['Small', 'Medium', 'Large', 'Very Large'])

# Impute with group median
df['mileage'] = df.groupby(['fuel', 'engine_category'])['mileage'].transform(
    lambda x: x.fillna(x.median())
)

df.drop('engine_category', axis=1, inplace=True)

# Check result
print(df['mileage'].describe())
# Out:
# count      736.000000
# mean       203.722201
# std       3186.759449
# min          5.000000
# 25%         12.000000
# 50%         14.000000
# 75%         15.000000
# max      69000.000000
# Name: mileage, dtype: float64
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_16840\3376968997.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['mileage'] = df.groupby(['fuel', 'engine_category'])['mileage'].transform(

# %% [markdown]
# **Dropping 'colour' because it has no semantic value, 'types' because it is complektely null, 'waranty' because it is mostly null and 'used_for' because it is very variable **

# %%
df.drop(['used_for','colour','waranty','types'],axis=1,inplace=True)

# %% [markdown]
# **Removing Currency Symbol**

# %%
df['price'] = df['price'].str.replace("रू.","",regex=False).str.replace(",","",regex=False).str.strip() #removes the rupee symbol and commas in the price. 
df.loc[0,'price']=2475000
df.head()
# Out:
#                                                 name    price   transmisson  \
# 0  Hyundai | i20 Active S | TDi | 2015 | Hatchbac...  2475000     Manual2WD
# 1                    Excellent car on sale (Hyundai)   750000       Auto2WD
# 2                          TATA 407 Container (Tata)   700000  Manual - 2WD
# 3                        4x4 swaraj Mazda (Mahindra)   600000  Manual - 4WD
# 4        i20 Active good for used few time (Hyundai)      375    Auto - 2WD
#
#    make_year  mileage  engine_cc    fuel  kilometer_run
# 0       2015     14.0     1400.0  Petrol        42000.0
# 1       2005     11.0     1399.0  Petrol        87412.0
# 2       2013     12.0     2956.0  Diesel        60000.0
# 3       2017      NaN        NaN  Diesel        33516.0
# 4       2019     17.0     1200.0  Petrol         2400.0

# %% [markdown]
# There are some listings with name in Nepali but they are kept as it is because it is very difficult to extend semantic meaning from them.

# %% [markdown]
# **Changing the transmission column into transmission_type and drive**

# %%
def split_transmisson(value):
    
    #first, let us check if the value is none. 
    if pd.isna(value):
        return (None,None)

    #Lets seperate by space
    value = value.strip()

    #If - is in the value then seperate by that value
    if '-' in value:
        parts = [p.strip() for p in value.split('-')]
        if len(parts) == 2:
            transmission_type = parts[0]
            drive = parts[1]
            return (transmission_type, drive)

    #Finally if the - doesn't exist we seperate alphabetic and numeric/WD parts 
    match = re.match(r"([A-Za-z]+)(.*)", value)
    if match:
        transmission_type = match.group(1)
        drive = match.group(2)
        return(transmission_type,drive)

    return(value,None)  

df[['transmisson_type','drive']] = df['transmisson'].apply(lambda x: pd.Series(split_transmisson(x)))
df.drop('transmisson', axis=1, inplace=True)
df.head()
# Out:
#                                                 name    price  make_year  \
# 0  Hyundai | i20 Active S | TDi | 2015 | Hatchbac...  2475000       2015
# 1                    Excellent car on sale (Hyundai)   750000       2005
# 2                          TATA 407 Container (Tata)   700000       2013
# 3                        4x4 swaraj Mazda (Mahindra)   600000       2017
# 4        i20 Active good for used few time (Hyundai)      375       2019
#
#    mileage  engine_cc    fuel  kilometer_run transmisson_type drive
# 0     14.0     1400.0  Petrol        42000.0           Manual   2WD
# 1     11.0     1399.0  Petrol        87412.0             Auto   2WD
# 2     12.0     2956.0  Diesel        60000.0           Manual   2WD
# 3      NaN        NaN  Diesel        33516.0           Manual   4WD
# 4     17.0     1200.0  Petrol         2400.0             Auto   2WD

# %% [markdown]
# **Discovery of Outliers in the Numeric Data**

# %%
def find_quartiles_and_outliers(columns):
    for column in columns:
        print(f"\n\n For the {column}")
        df[column] = pd.to_numeric(df[column],errors='coerce')
        Q1 = df[column].quantile(0.25)
        Q2 = df[column].mean()
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        print(f"Q1:{Q1} ,Q2:{Q2} ,Q3:{Q3} , IQR:{IQR}") 
        outliers = df[(df[column] < (Q1 - 1.5* IQR)) | (df[column] > (Q3 + 1.5 * IQR))]
        print(f"Number of Outliers: {len(outliers)}")

find_quartiles_and_outliers(['kilometer_run','engine_cc','price','mileage','make_year'])
# Out:
#  For the kilometer_run
# Q1:32891.0 ,Q2:57927.2712264151 ,Q3:67274.0 , IQR:34383.0
# Number of Outliers: 22
#
#
#  For the engine_cc
# Q1:1197.0 ,Q2:1520.64689608637 ,Q3:1600.0 , IQR:403.0
# Number of Outliers: 112
#
#
#  For the price
# Q1:1175000.0 ,Q2:2334365.9572446556 ,Q3:2650000.0 , IQR:1475000.0
# Number of Outliers: 68
#
#
#  For the mileage
# Q1:12.0 ,Q2:203.7222010869565 ,Q3:15.0 , IQR:3.0
# Number of Outliers: 39
#
#
#  For the make_year
# Q1:2010.0 ,Q2:1999.9870283018868 ,Q3:2017.0 , IQR:7.0
# Number of Outliers: 22

# %% [markdown]
# Special for Kilometers Run

# %%
def find_quartiles_and_outliers_print(columns):
    for column in columns:
        print(f"\n\n For the {column}")
        df[column] = pd.to_numeric(df[column],errors='coerce')
        Q1 = df[column].quantile(0.25)
        Q2 = df[column].mean()
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        print(f"Q1:{Q1} ,Q2:{Q2} ,Q3:{Q3} , IQR:{IQR}") 
        outliers = df[(df[column] < (Q1 - 1.5* IQR)) | (df[column] > (Q3 + 1.5 * IQR))]
        print(outliers[column])
        print(f"Number of Outliers: {len(outliers)}")

# %%
find_quartiles_and_outliers_print(['kilometer_run'])
# Out:
#  For the kilometer_run
# Q1:32891.0 ,Q2:57927.2712264151 ,Q3:67274.0 , IQR:34383.0
# 37      750840.0
# 175     610000.0
# 222     130000.0
# 267     790000.0
# 271     155000.0
# 311    1700000.0
# 325     146000.0
# 427     485780.0
# 441     320000.0
# 476     127130.0
# 486     125000.0
# 491     560000.0
# 541     160000.0
# 557     143000.0
# 586     125000.0
# 588     140000.0
# 618     750000.0
# 656     150000.0
# 701    -172368.0
# 784     149000.0
# 811    1350000.0
# 820     180000.0
# Name: kilometer_run, dtype: float64
# Number of Outliers: 22

# %% [markdown]
# There is one negative value, making it positive and Removing the values more than 180000, since they are in millions.

# %%
df.loc[701,'kilometer_run']=172368

# %%
upper_bound=180000
df['kilometer_run'] = df['kilometer_run'].clip(upper=upper_bound)
find_quartiles_and_outliers_print(['kilometer_run'])
# Out:
#  For the kilometer_run
# Q1:33000.0 ,Q2:51616.08726415094 ,Q3:68000.0 , IQR:35000.0
# 37     180000.0
# 175    180000.0
# 222    130000.0
# 267    180000.0
# 271    155000.0
# 311    180000.0
# 325    146000.0
# 427    180000.0
# 441    180000.0
# 476    127130.0
# 486    125000.0
# 491    180000.0
# 541    160000.0
# 557    143000.0
# 586    125000.0
# 588    140000.0
# 618    180000.0
# 656    150000.0
# 701    172368.0
# 784    149000.0
# 811    180000.0
# 820    180000.0
# Name: kilometer_run, dtype: float64
# Number of Outliers: 22

# %% [markdown]
# **Special for Make Year**

# %%
find_quartiles_and_outliers_print(['make_year'])
# Out:
#  For the make_year
# Q1:2010.0 ,Q2:1999.9870283018868 ,Q3:2017.0 , IQR:7.0
# 42     1997
# 127    1975
# 255    1998
# 266    1997
# 275    1997
# 322    1998
# 325    1998
# 465    1975
# 472    1999
# 488       0
# 503    2069
# 565       0
# 575     207
# 603    1992
# 612    1999
# 661    1998
# 701    2060
# 711     202
# 757      13
# 805     207
# 825    1993
# 827    1999
# Name: make_year, dtype: int64
# Number of Outliers: 22

# %% [markdown]
# Dropping 0 values, Manually changing 2069 and 2060 to AD, 13 to 2013 and 207 and 202 to 2007 and 2002

# %%
df = df.drop([488,565])
find_quartiles_and_outliers_print(['make_year'])
# Out:
#  For the make_year
# Q1:2010.0 ,Q2:2004.7151300236408 ,Q3:2017.0 , IQR:7.0
# 42     1997
# 127    1975
# 255    1998
# 266    1997
# 275    1997
# 322    1998
# 325    1998
# 465    1975
# 472    1999
# 503    2069
# 575     207
# 603    1992
# 612    1999
# 661    1998
# 701    2060
# 711     202
# 757      13
# 805     207
# 825    1993
# 827    1999
# Name: make_year, dtype: int64
# Number of Outliers: 20

# %%
df.loc[503,'make_year']= 2012
df.loc[575,'make_year']= 2007
df.loc[701,'make_year']= 2003
df.loc[711,'make_year']= 2002
df.loc[757,'make_year']= 2013
df.loc[805,'make_year']= 2007
find_quartiles_and_outliers_print(['make_year'])
# Out:
#  For the make_year
# Q1:2010.0 ,Q2:2013.3274231678488 ,Q3:2017.0 , IQR:7.0
# 42     1997
# 127    1975
# 255    1998
# 266    1997
# 275    1997
# 322    1998
# 325    1998
# 465    1975
# 472    1999
# 603    1992
# 612    1999
# 661    1998
# 825    1993
# 827    1999
# Name: make_year, dtype: int64
# Number of Outliers: 14

# %% [markdown]
# **Now for the mileage**

# %%
print(df[df['mileage'] > 100]['mileage'].describe())
# Out:
# count       11.000000
# mean     12688.181818
# std      23924.354774
# min        120.000000
# 25%        270.000000
# 50%        400.000000
# 75%       8512.500000
# max      69000.000000
# Name: mileage, dtype: float64

# %% [markdown]
# **Keeping price,engine_cc outliers because they are genuine data, Capping the mileage outliers at the IQR**

# %%
Q1_m = df['mileage'].quantile(0.25)
Q3_m = df['mileage'].quantile(0.75)
IQR_m = Q3_m - Q1_m
df['mileage'] = df['mileage'].clip(
    lower=Q1_m - 1.5*IQR_m,
    upper=Q3_m + 1.5*IQR_m
)

# %% [markdown]
# **Handling the missing Values**

# %%
print(df['kilometer_run'].isna().sum())
print(df['price'].isna().sum())
print(df['engine_cc'].isna().sum())
print(df['mileage'].isna().sum())
print(df['make_year'].isna().sum())
# Out:
# 0
# 6
# 105
# 110
# 0

# %% [markdown]
# Using median and mode for the numerical data.

# %%
df['price'] = df['price'].fillna(df['price'].median())
df['engine_cc'] = df['engine_cc'].fillna(df['engine_cc'].mode()[0])
df['mileage'] = df['mileage'].fillna(df['mileage'].median())

# %% [markdown]
# Binary Encoding for Transmission Type

# %%
print(df['transmisson_type'].value_counts())
# Out:
# transmisson_type
# Manual           621
# Auto             180
# Power             28
# PowerSteering     17
# Name: count, dtype: int64

# %% [markdown]
# Keeping power steering also as manual because it is too small dataset to be another feature and mostly power steering is used in heavy vehicle.

# %%
df['is_automatic'] = (df['transmisson_type'] == 'Auto').astype(int)
df.drop('transmisson_type', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                 name      price  make_year  \
# 0  Hyundai | i20 Active S | TDi | 2015 | Hatchbac...  2475000.0       2015
# 1                    Excellent car on sale (Hyundai)   750000.0       2005
# 2                          TATA 407 Container (Tata)   700000.0       2013
# 3                        4x4 swaraj Mazda (Mahindra)   600000.0       2017
# 4        i20 Active good for used few time (Hyundai)      375.0       2019
#
#    mileage  engine_cc    fuel  kilometer_run drive  is_automatic
# 0     14.0     1400.0  Petrol        42000.0   2WD             0
# 1     11.0     1399.0  Petrol        87412.0   2WD             1
# 2     12.0     2956.0  Diesel        60000.0   2WD             0
# 3     14.0     1200.0  Diesel        33516.0   4WD             0
# 4     17.0     1200.0  Petrol         2400.0   2WD             1

# %% [markdown]
# Binary Encoding for Drive

# %%
print(df['drive'].value_counts())
# Out:
# drive
# 2WD          645
# 4WD          156
#  Steering     28
#               17
# Name: count, dtype: int64

# %% [markdown]
# Keeping others at 2WD

# %%
df['is_4WD'] = (df['drive'] == '4WD').astype(int)
df.drop('drive', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                 name      price  make_year  \
# 0  Hyundai | i20 Active S | TDi | 2015 | Hatchbac...  2475000.0       2015
# 1                    Excellent car on sale (Hyundai)   750000.0       2005
# 2                          TATA 407 Container (Tata)   700000.0       2013
# 3                        4x4 swaraj Mazda (Mahindra)   600000.0       2017
# 4        i20 Active good for used few time (Hyundai)      375.0       2019
#
#    mileage  engine_cc    fuel  kilometer_run  is_automatic  is_4WD
# 0     14.0     1400.0  Petrol        42000.0             0       0
# 1     11.0     1399.0  Petrol        87412.0             1       0
# 2     12.0     2956.0  Diesel        60000.0             0       0
# 3     14.0     1200.0  Diesel        33516.0             0       1
# 4     17.0     1200.0  Petrol         2400.0             1       0

# %% [markdown]
# Encoding for Fuel

# %%
print(df['fuel'].value_counts())
# Out:
# fuel
# Petrol      602
# Diesel      221
# Electric     18
# Hybrid        5
# Name: count, dtype: int64

# %% [markdown]
# Ordinal Encoding

# %%
fuel_order = {
    "Petrol": 1,
    "Diesel": 2,
    "Electric": 3,
    "Hybrid": 4
}

df['fuel'] = df['fuel'].map(fuel_order)
df.head()
# Out:
#                                                 name      price  make_year  \
# 0  Hyundai | i20 Active S | TDi | 2015 | Hatchbac...  2475000.0       2015
# 1                    Excellent car on sale (Hyundai)   750000.0       2005
# 2                          TATA 407 Container (Tata)   700000.0       2013
# 3                        4x4 swaraj Mazda (Mahindra)   600000.0       2017
# 4        i20 Active good for used few time (Hyundai)      375.0       2019
#
#    mileage  engine_cc  fuel  kilometer_run  is_automatic  is_4WD
# 0     14.0     1400.0     1        42000.0             0       0
# 1     11.0     1399.0     1        87412.0             1       0
# 2     12.0     2956.0     2        60000.0             0       0
# 3     14.0     1200.0     2        33516.0             0       1
# 4     17.0     1200.0     1         2400.0             1       0

# %% [markdown]
# Finally changing make year into age.

# %%
df['age'] = 2025 - df['make_year']
df.drop('make_year',axis=1,inplace=True)
df.head()
# Out:
#                                                 name      price  mileage  \
# 0  Hyundai | i20 Active S | TDi | 2015 | Hatchbac...  2475000.0     14.0
# 1                    Excellent car on sale (Hyundai)   750000.0     11.0
# 2                          TATA 407 Container (Tata)   700000.0     12.0
# 3                        4x4 swaraj Mazda (Mahindra)   600000.0     14.0
# 4        i20 Active good for used few time (Hyundai)      375.0     17.0
#
#    engine_cc  fuel  kilometer_run  is_automatic  is_4WD  age
# 0     1400.0     1        42000.0             0       0   10
# 1     1399.0     1        87412.0             1       0   20
# 2     2956.0     2        60000.0             0       0   12
# 3     1200.0     2        33516.0             0       1    8
# 4     1200.0     1         2400.0             1       0    6

# %% [markdown]
# **Saving the Cleaned Data**

# %%
df.to_csv("cleaned_data.csv", index=False)
